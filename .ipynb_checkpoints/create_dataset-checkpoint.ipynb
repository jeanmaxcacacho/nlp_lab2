# %% [markdown]
# ### A General Flow of Dataset Creation
# 1. load the CSV into a pandas dataframe
# 2. clean the text for tokenization
# 3. get `max_length` from getting length of tokenized reviews
# 4. write out `reviews_as_table` as a `.txt` file
#    - join all 50000 entries into one big string (corpus from which we will form our vocabulary from)
#    - separate reviews into a list of lists of containing 50000 lists where each list contains the group of tokens for a review (feature vector representation)
# ### Nice to haves for Thursday Probs
# - have the `max_length`
# - a vector representation for each and every review (this predicates on us having the corpus vocab)

# %%
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.corpus import stopwords
from nltk.util import bigrams
nltk.download('punkt')
nltk.download('wordnet')
import re
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\cacac\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\cacac\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # Load into environment as Pandas DF

# %%
reviews_as_table = pd.read_csv('IMDB Dataset.csv')
reviews_as_table
# Out:
#                                                   review sentiment
# 0      One of the other reviewers has mentioned that ...  positive
# 1      A wonderful little production. <br /><br />The...  positive
# 2      I thought this was a wonderful way to spend ti...  positive
# 3      Basically there's a family where a little boy ...  negative
# 4      Petter Mattei's "Love in the Time of Money" is...  positive
# ...                                                  ...       ...
# 49995  I thought this movie did a down right good job...  positive
# 49996  Bad plot, bad dialogue, bad acting, idiotic di...  negative
# 49997  I am a Catholic taught in parochial elementary...  negative
# 49998  I'm going to have to disagree with the previou...  negative
# 49999  No one expects the Star Trek movies to be high...  negative
#
# [50000 rows x 2 columns]

# %% [markdown]
# # This cell was to test if I knew how to use Pandas

# %%
reviews_as_table["cleaned"] = reviews_as_table["review"].str.lower()
reviews_as_table.head()
# Out:
#                                               review sentiment  \
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive
#
#                                              cleaned
# 0  one of the other reviewers has mentioned that ...
# 1  a wonderful little production. <br /><br />the...
# 2  i thought this was a wonderful way to spend ti...
# 3  basically there's a family where a little boy ...
# 4  petter mattei's "love in the time of money" is...

# %% [markdown]
# # Stolen pre-processing steps from module 1 examples & lab

# %%
reviews_as_table["cleaned"] = reviews_as_table["cleaned"].apply(lambda x: re.sub(r'[^\x00-\x7f]', r'', x))
reviews_as_table["cleaned"] = reviews_as_table["cleaned"].apply(lambda x: x.replace(".<br /><br />",".<br /><br /><s>"))
reviews_as_table["cleaned"] = reviews_as_table["cleaned"].apply(lambda x: x.replace(". <br /><br />",". <br /><br /><s>"))
reviews_as_table["cleaned"] = reviews_as_table["cleaned"].apply(lambda x: "<s> " + x)

reviews_as_table
# Out:
#                                                   review sentiment  \
# 0      One of the other reviewers has mentioned that ...  positive
# 1      A wonderful little production. <br /><br />The...  positive
# 2      I thought this was a wonderful way to spend ti...  positive
# 3      Basically there's a family where a little boy ...  negative
# 4      Petter Mattei's "Love in the Time of Money" is...  positive
# ...                                                  ...       ...
# 49995  I thought this movie did a down right good job...  positive
# 49996  Bad plot, bad dialogue, bad acting, idiotic di...  negative
# 49997  I am a Catholic taught in parochial elementary...  negative
# 49998  I'm going to have to disagree with the previou...  negative
# 49999  No one expects the Star Trek movies to be high...  negative
#
#                                                  cleaned
# 0      <s> one of the other reviewers has mentioned t...
# 1      <s> a wonderful little production. <br /><br /...
# 2      <s> i thought this was a wonderful way to spen...
# 3      <s> basically there's a family where a little ...
# 4      <s> petter mattei's "love in the time of money...
# ...                                                  ...
# 49995  <s> i thought this movie did a down right good...
# 49996  <s> bad plot, bad dialogue, bad acting, idioti...
# 49997  <s> i am a catholic taught in parochial elemen...
# 49998  <s> i'm going to have to disagree with the pre...
# 49999  <s> no one expects the star trek movies to be ...
#
# [50000 rows x 3 columns]

# %% [markdown]
# # Tokenization

# %%
def custom_tokenize(text):
    text = text.replace("<s>", " SPECIAL_START_TOKEN ").replace("</s>", " SPECIAL_END_TOKEN ")
    tokens = word_tokenize(text)
    tokens = [token.replace("SPECIAL_START_TOKEN", "<s>").replace("SPECIAL_END_TOKEN", "</s>") for token in tokens]
    return tokens

reviews_as_table["cleaned_tokenized"] = reviews_as_table["cleaned"].apply(lambda x: custom_tokenize(str(x)))
reviews_as_table
# Out:
#                                                   review sentiment  \
# 0      One of the other reviewers has mentioned that ...  positive
# 1      A wonderful little production. <br /><br />The...  positive
# 2      I thought this was a wonderful way to spend ti...  positive
# 3      Basically there's a family where a little boy ...  negative
# 4      Petter Mattei's "Love in the Time of Money" is...  positive
# ...                                                  ...       ...
# 49995  I thought this movie did a down right good job...  positive
# 49996  Bad plot, bad dialogue, bad acting, idiotic di...  negative
# 49997  I am a Catholic taught in parochial elementary...  negative
# 49998  I'm going to have to disagree with the previou...  negative
# 49999  No one expects the Star Trek movies to be high...  negative
#
#                                                  cleaned  \
# 0      <s> one of the other reviewers has mentioned t...
# 1      <s> a wonderful little production. <br /><br /...
# 2      <s> i thought this was a wonderful way to spen...
# 3      <s> basically there's a family where a little ...
# 4      <s> petter mattei's "love in the time of money...
# ...                                                  ...
# 49995  <s> i thought this movie did a down right good...
# 49996  <s> bad plot, bad dialogue, bad acting, idioti...
# 49997  <s> i am a catholic taught in parochial elemen...
# 49998  <s> i'm going to have to disagree with the pre...
# 49999  <s> no one expects the star trek movies to be ...
#
#                                        cleaned_tokenized
# 0      [<s>, one, of, the, other, reviewers, has, men...
# 1      [<s>, a, wonderful, little, production, ., <, ...
# 2      [<s>, i, thought, this, was, a, wonderful, way...
# 3      [<s>, basically, there, 's, a, family, where, ...
# 4      [<s>, petter, mattei, 's, ``, love, in, the, t...
# ...                                                  ...
# 49995  [<s>, i, thought, this, movie, did, a, down, r...
# 49996  [<s>, bad, plot, ,, bad, dialogue, ,, bad, act...
# 49997  [<s>, i, am, a, catholic, taught, in, parochia...
# 49998  [<s>, i, 'm, going, to, have, to, disagree, wi...
# 49999  [<s>, no, one, expects, the, star, trek, movie...
#
# [50000 rows x 4 columns]

# %% [markdown]
# # Counting

# %%
reviews_as_table["cleaned_tokenized_counts"] = reviews_as_table["cleaned_tokenized"].apply(lambda x: len(x))
reviews_as_table
# Out:
#                                                   review sentiment  \
# 0      One of the other reviewers has mentioned that ...  positive
# 1      A wonderful little production. <br /><br />The...  positive
# 2      I thought this was a wonderful way to spend ti...  positive
# 3      Basically there's a family where a little boy ...  negative
# 4      Petter Mattei's "Love in the Time of Money" is...  positive
# ...                                                  ...       ...
# 49995  I thought this movie did a down right good job...  positive
# 49996  Bad plot, bad dialogue, bad acting, idiotic di...  negative
# 49997  I am a Catholic taught in parochial elementary...  negative
# 49998  I'm going to have to disagree with the previou...  negative
# 49999  No one expects the Star Trek movies to be high...  negative
#
#                                                  cleaned  \
# 0      <s> one of the other reviewers has mentioned t...
# 1      <s> a wonderful little production. <br /><br /...
# 2      <s> i thought this was a wonderful way to spen...
# 3      <s> basically there's a family where a little ...
# 4      <s> petter mattei's "love in the time of money...
# ...                                                  ...
# 49995  <s> i thought this movie did a down right good...
# 49996  <s> bad plot, bad dialogue, bad acting, idioti...
# 49997  <s> i am a catholic taught in parochial elemen...
# 49998  <s> i'm going to have to disagree with the pre...
# 49999  <s> no one expects the star trek movies to be ...
#
#                                        cleaned_tokenized  \
# 0      [<s>, one, of, the, other, reviewers, has, men...
# 1      [<s>, a, wonderful, little, production, ., <, ...
# 2      [<s>, i, thought, this, was, a, wonderful, way...
# 3      [<s>, basically, there, 's, a, family, where, ...
# 4      [<s>, petter, mattei, 's, ``, love, in, the, t...
# ...                                                  ...
# 49995  [<s>, i, thought, this, movie, did, a, down, r...
# 49996  [<s>, bad, plot, ,, bad, dialogue, ,, bad, act...
# 49997  [<s>, i, am, a, catholic, taught, in, parochia...
# 49998  [<s>, i, 'm, going, to, have, to, disagree, wi...
# 49999  [<s>, no, one, expects, the, star, trek, movie...
#
#        cleaned_tokenized_counts
# 0                           384
# 1                           205
# 2                           208
# 3                           179
# 4                           288
# ...                         ...
# 49995                       243
# 49996                       141
# 49997                       274
# 49998                       241
# 49999                       152
#
# [50000 rows x 5 columns]

# %% [markdown]
# ### obtaining `max_length`

# %%
reviews_as_table["cleaned_tokenized_counts"].max()
# Out:
# 2944

# %% [markdown]
# ### longest entries

# %%
longest_to_shortest = reviews_as_table.sort_values(by='cleaned_tokenized_counts', ascending=False)
longest_to_shortest.head(10)
# Out:
#                                                   review sentiment  \
# 40521  There's a sign on The Lost Highway that says:<...  positive
# 31481  Match 1: Tag Team Table Match Bubba Ray and Sp...  positive
# 31240  (Some spoilers included:)<br /><br />Although,...  positive
# 31436  Back in the mid/late 80s, an OAV anime by titl...  positive
# 5708   **Attention Spoilers**<br /><br />First of all...  positive
# 3654   *!!- SPOILERS - !!*<br /><br />Before I begin ...  positive
# 42946  By now you've probably heard a bit about the n...  positive
# 12647  Titanic directed by James Cameron presents a f...  positive
# 3024   If anyone ever assembles a compendium on moder...  positive
# 43821  Some have praised _Atlantis:_The_Lost_Empire_ ...  negative
#
#                                                  cleaned  \
# 40521  <s> there's a sign on the lost highway that sa...
# 31481  <s> match 1: tag team table match bubba ray an...
# 31240  <s> (some spoilers included:)<br /><br />altho...
# 31436  <s> back in the mid/late 80s, an oav anime by ...
# 5708   <s> **attention spoilers**<br /><br />first of...
# 3654   <s> *!!- spoilers - !!*<br /><br />before i be...
# 42946  <s> by now you've probably heard a bit about t...
# 12647  <s> titanic directed by james cameron presents...
# 3024   <s> if anyone ever assembles a compendium on m...
# 43821  <s> some have praised _atlantis:_the_lost_empi...
#
#                                        cleaned_tokenized  \
# 40521  [<s>, there, 's, a, sign, on, the, lost, highw...
# 31481  [<s>, match, 1, :, tag, team, table, match, bu...
# 31240  [<s>, (, some, spoilers, included, :, ), <, br...
# 31436  [<s>, back, in, the, mid/late, 80s, ,, an, oav...
# 5708   [<s>, *, *, attention, spoilers, *, *, <, br, ...
# 3654   [<s>, *, !, !, -, spoilers, -, !, !, *, <, br,...
# 42946  [<s>, by, now, you, 've, probably, heard, a, b...
# 12647  [<s>, titanic, directed, by, james, cameron, p...
# 3024   [<s>, if, anyone, ever, assembles, a, compendi...
# 43821  [<s>, some, have, praised, _atlantis, :, _the_...
#
#        cleaned_tokenized_counts
# 40521                      2944
# 31481                      2819
# 31240                      2670
# 31436                      2575
# 5708                       2321
# 3654                       2134
# 42946                      2046
# 12647                      2028
# 3024                       2020
# 43821                      1947

# %% [markdown]
# ### shortest entries

# %%
longest_to_shortest.tail(10)
# Out:
#                                                   review sentiment  \
# 48448  Adrian Pasdar is excellent is this film. He ma...  positive
# 31761  Ming The Merciless does a little Bardwork and ...  negative
# 31072          What a script, what a story, what a mess!  negative
# 13109  More suspenseful, more subtle, much, much more...  negative
# 11926  I wouldn't rent this one even on dollar rental...  negative
# 19874  This movie is terrible but it has some good ef...  negative
# 18400  Brilliant and moving performances by Tom Court...  positive
# 40817  I hope this group of film-makers never re-unites.  negative
# 28920  Primary plot!Primary direction!Poor interpreta...  negative
# 27521                   Read the book, forget the movie!  negative
#
#                                                  cleaned  \
# 48448  <s> adrian pasdar is excellent is this film. h...
# 31761  <s> ming the merciless does a little bardwork ...
# 31072      <s> what a script, what a story, what a mess!
# 13109  <s> more suspenseful, more subtle, much, much ...
# 11926  <s> i wouldn't rent this one even on dollar re...
# 19874  <s> this movie is terrible but it has some goo...
# 18400  <s> brilliant and moving performances by tom c...
# 40817  <s> i hope this group of film-makers never re-...
# 28920  <s> primary plot!primary direction!poor interp...
# 27521               <s> read the book, forget the movie!
#
#                                        cleaned_tokenized  \
# 48448  [<s>, adrian, pasdar, is, excellent, is, this,...
# 31761  [<s>, ming, the, merciless, does, a, little, b...
# 31072  [<s>, what, a, script, ,, what, a, story, ,, w...
# 13109  [<s>, more, suspenseful, ,, more, subtle, ,, m...
# 11926  [<s>, i, would, n't, rent, this, one, even, on...
# 19874  [<s>, this, movie, is, terrible, but, it, has,...
# 18400  [<s>, brilliant, and, moving, performances, by...
# 40817  [<s>, i, hope, this, group, of, film-makers, n...
# 28920  [<s>, primary, plot, !, primary, direction, !,...
# 27521   [<s>, read, the, book, ,, forget, the, movie, !]
#
#        cleaned_tokenized_counts
# 48448                        15
# 31761                        14
# 31072                        13
# 13109                        13
# 11926                        13
# 19874                        12
# 18400                        12
# 40817                        10
# 28920                        10
# 27521                         9
